# %% [markdown]
# <a href="https://colab.research.google.com/github/au312821243036/CODSOFT/blob/main/Credit_Crad_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import scipy

# %%
data = pd.read_csv(r'/content/creditcard.csv')

# %%
print(data.columns)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data = data.sample(frac=0.1, random_state = 1)
print(data.shape)
print(data.describe())
# Out:
# (397, 31)
#               Time          V1          V2          V3          V4  \
# count   397.000000  397.000000  397.000000  397.000000  397.000000
# mean   1551.816121   -0.235088    0.266909    0.854623    0.108522
# std    1014.548113    1.280494    1.091998    1.015085    1.363811
# min       4.000000   -4.636534   -5.931717   -3.753719   -4.434211
# 25%     658.000000   -0.983810   -0.233544    0.249270   -0.806651
# 50%    1368.000000   -0.421336    0.331464    0.861225    0.194524
# 75%    2426.000000    1.073785    0.891789    1.514355    1.067438
# max    3617.000000    1.586093    5.684778    3.770236    3.551137
#
#                V5          V6          V7          V8          V9  ...  \
# count  397.000000  397.000000  397.000000  397.000000  397.000000  ...
# mean     0.011675    0.088292    0.091446   -0.023682    0.048196  ...
# std      1.097382    1.240208    0.772999    1.032149    0.825604  ...
# min     -3.205115   -3.047061   -4.417815  -12.258158   -2.517037  ...
# 25%     -0.633109   -0.702025   -0.321262   -0.173346   -0.462702  ...
# 50%     -0.139087   -0.156067    0.081123    0.045212    0.050946  ...
# 75%      0.417759    0.486831    0.573980    0.301837    0.617402  ...
# max      7.672544    4.683822    3.310782    2.306227    4.390536  ...
#
#               V21         V22         V23         V24         V25         V26  \
# count  397.000000  397.000000  397.000000  397.000000  397.000000  397.000000
# mean    -0.042822   -0.111412   -0.031715    0.049169    0.087602    0.018717
# std      0.526070    0.596734    0.290131    0.606301    0.412156    0.498695
# min     -3.509804   -2.900495   -0.977008   -1.765507   -1.420755   -0.984011
# 25%     -0.221714   -0.556324   -0.186645   -0.324377   -0.165969   -0.318168
# 50%     -0.074659   -0.145878   -0.066621    0.085004    0.089020   -0.002554
# 75%      0.083873    0.313584    0.066026    0.475347    0.366134    0.330559
# max      5.740097    1.957759    1.501474    1.099438    1.114332    1.439247
#
#               V27         V28       Amount  Class
# count  397.000000  397.000000   397.000000  397.0
# mean     0.036381    0.012875    58.100428    0.0
# std      0.311703    0.195860   118.095968    0.0
# min     -2.887661   -1.683655     0.000000    0.0
# 25%     -0.057110   -0.021742     3.160000    0.0
# 50%      0.022118    0.017547    13.080000    0.0
# 75%      0.212042    0.083138    59.900000    0.0
# max      1.602367    0.983275  1127.780000    0.0
#
# [8 rows x 31 columns]

# %%
data.hist(figsize = (30, 30))
plt.show()

# %%
Fraud = data[data['Class'] == 1]
Valid = data[data['Class'] == 0]

outlier_fraction = len(Fraud)/float(len(Valid))
print(outlier_fraction)

print('Fraud Cases: {}'.format(len(data[data['Class'] == 1])))
print('Valid Transactions: {}'.format(len(data[data['Class'] == 0])))
# Out:
# 0.0
# Fraud Cases: 0
# Valid Transactions: 397

# %%
corrmat = data.corr()
fig = plt.figure(figsize = (10, 7))

sns.heatmap(corrmat, vmax = .6, square = True)
plt.show()

# %%
columns = data.columns.tolist()
columns = [c for c in columns if c not in ["Class"]]
target = "Class"
X = data[columns]
Y = data[target]
print(X.shape)
print(Y.shape)
# Out:
# (397, 30)
# (397,)
